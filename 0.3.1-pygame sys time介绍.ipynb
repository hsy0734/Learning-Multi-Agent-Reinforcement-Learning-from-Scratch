# %%
import pygame
import sys  #sys.argv 处理命令行参数、sys.exit() 退出程序、
            #sys.path 管理模块路径
import time #time.sleep(1) 使程序暂停1秒

# 1. 初始化 Pygame 虽然大多数库不初始化也能用，但是为了避免一些潜在问题，建议初始化
pygame.init()

# 2. 创建游戏窗口（宽度400，高度300）有两个括号说明是元组，元组是不可变的列表
screen = pygame.display.set_mode((400, 300))
# 设置窗口标题
pygame.display.set_caption("我的第一个Pygame窗口")

# 3. 游戏主循环（核心：持续监听事件、更新画面）
running = True
while running:
    # 监听事件 捕获我们关闭窗口的事件
    for event in pygame.event.get():
        # 处理窗口关闭事件
        if event.type == pygame.QUIT:
            running = False

    # 填充窗口背景色（RGB：浅灰色）
    screen.fill((240, 240, 240))
    # 更新画面（必须调用，否则绘制内容不显示）
    pygame.display.flip()

    #调用time.sleep(1)函数，使程序暂停1秒
    time.sleep(1)

    screen.fill((24, 24, 24))
    # 更新画面（必须调用，否则绘制内容不显示）
    pygame.display.flip()
    
    # 控制帧率为60帧/秒
    clock.tick(60)

# 4. 退出Pygame，关闭程序
pygame.quit()
sys.exit()
